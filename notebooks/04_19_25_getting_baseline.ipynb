# %% [markdown]
# # Getting a Baseline
#
# The purpose of this notebook is to instantiate the research structure as well as see if a baseline model can be developed, from which further models can be compared to.

# %% [markdown]
# ### Hypothesis 1: Developing a baseline model is trivial.

# %%
# %run ../src/cfb/backtest.py --name "baseline"
# Out:
# Step 1: Loading data...
# Step 2: Preprocess and separate odds, X, and y...
# Step 3: Training and evaluating the model...
# Success!

# %% [markdown]
# ### Result 1: Accepted.
# We can indeed generated a model. The baseline model can be found in the "src/cfb/models/baseline_total_pipeline.pkl" file.

# %% [markdown]
# ### Hypothesis 2: We can trivially generate metrics for the baseline.

# %%
from cfb.evaluation import plot_pnl, get_pred_metrics, plot_model_metrics

plot_pnl("baseline")
plot_model_metrics("baseline")
get_pred_metrics("baseline")
# Out:
#                                   Mean Average Error  Mean Squared Error  \
# model
# baseline_total_simple_percentage           14.673297          336.376082
#
#                                   R-Squared    Sharpe  Net PNL  Max Drawdown  \
# model
# baseline_total_simple_percentage  -0.034353  1.129085  -107.89       -125.71
#
#                                   Number of Bets  Winning Bet %
# model
# baseline_total_simple_percentage            3012       0.515604

# %% [markdown]
# ### Result 2: Accepted
#
# The functions properly provide the necessary info. As a result, we indeed have a working baseline to compare later models and performance with.
